# %% [markdown]
# <a href="https://colab.research.google.com/github/walukas1/DeepDiveDSProjects/blob/main/Capstone_NMPED_Attendance_Data_scraping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #TO DO
#
#
# 1. ✅Automate data scraping of NM PED site/Manually scrape
# 1. ✅Initial data analysis to see what there is
# 1. ✅Make common dataframe columns uniform
#   1. ✅Drop unneeded columns
#   1. ✅Add school, district and year columns
# 1. ✅Rearrange column order
# 1. ✅Compile like dataframes with
#
# [✅ Complete] ---
# [🟡 In progress] ---
# [❗ Backlog]

# %% [markdown]
# Source : https://webnew.ped.state.nm.us/bureaus/safe-healthy-schools/attendance-for-success/annual-state-districts-and-schools-attendance-report/

# %%
import re
import requests
import pandas as pd
from bs4 import BeautifulSoup as bs4

# %%
highland_list = ['Wherry Elementary',
'Emerson Elementary',
'Whittier Elementary',
'Wilson Middle',
'Van Buren Middle',
'Hayes Middle',
'Highland High']

# %% [markdown]
# ## ✅Try to pull file addresses directly from main site page
#
# Attempt made, less possible due to each school report having a unique web address identifier

# %%
# url = "https://webnew.ped.state.nm.us/bureaus/safe-healthy-schools/attendance-for-success/annual-state-districts-and-schools-attendance-report/"
# url

# %%
# response = requests.get( url )
# response.text[:500]

# %%
# dom = bs4( response.text, features='html.parser')
# type(dom), str(dom)[:500]

# %%
# data_links = [
#  x.group(0)
#     for link_tag in dom.find_all('a', href=True)
#       if (x := re.search(r'https://.*\.(xls(x|b)?|csv|txt|tsv)$', link_tag['href'], re.IGNORECASE))
# ]
# len(data_links)

# %%
# data_links

# %% [markdown]
# ### Example file addresses, parsed

# %%
# https://nmpedpublic.cloud.looker.com/explore/fnojb7yxyCV4ZwcYk05ylZ.json_label
# ?apply_formatting=true
# &apply_vis=true
# &open_in_browser=yes
# &title=Subpopulation%20Attendance%20Data%20-%20School
# &filename=Subpopulation%20Attendance%20Data%20-%20School
# .json_label

# %%
# https://nmpedpublic.cloud.looker.com/explore/zCnQiRkprRU49DA0cfxvyF.json_label
# ?apply_formatting=true&apply_vis=true
# &open_in_browser=yes
# &title=Overview%20of%20School%20Attendance%20Information%20by%20Grade%20Level
# &filename=Overview%20of%20School%20Attendance%20Information%20by%20Grade%20Level
# .json_label

# %% [markdown]
# ### ✅EDA for file formatting options

# %% [markdown]
# unformatted

# %%
aps24_att_url = 'https://nmpedpublic.cloud.looker.com/explore/X0z1FpGXo4Dk9cxgdxkbcR.json_label?apply_formatting=false&apply_vis=false&open_in_browser=yes&title=Overview%20of%20School%20Attendance%20Information%20by%20Grade%20Level&filename=Overview%20of%20School%20Attendance%20Information%20by%20Grade%20Level.json_label'
# response = requests.get(aps_att_url)
aps24_att_byschool = pd.read_json(aps24_att_url)

# %%
aps24_att_byschool.tail()
filter = aps24_att_byschool['Annual Attendance  School Name'] == 'WHITTIER ELEMENTARY'
filter2 = aps24_att_byschool['Annual Attendance Grade Level'] == '09'
aps24_att_byschool[filter]
# Out:
#     Annual Attendance  District Name Annual Attendance  School Name  \
# 422                     ALBUQUERQUE             WHITTIER ELEMENTARY
# 493                     ALBUQUERQUE             WHITTIER ELEMENTARY
#
#     Annual Attendance Grade Level  Annual Attendance Enrollment  \
# 422                            05                          57.0
# 493                            02                          50.0
#
#      Annual Attendance No. of Student in Tier 1  \
# 422                                        13.0
# 493                                        12.0
#
#      Annual Attendance No. of Student in Tier 2  \
# 422                                        21.0
# 493                                        10.0
#
#      Annual Attendance No. of Student in Tier 3  \
# 422                                        15.0
# 493                                        19.0
#
#      Annual Attendance No. of Student in Tier 4  \
# 422                                         8.0
# ...

# %%
aps24_subgroup_url = 'https://nmpedpublic.cloud.looker.com/explore/HwOnfWOWUATBnL9Bdv6dkS.json_label?apply_formatting=false&apply_vis=false&open_in_browser=yes&title=Subpopulation%20Attendance%20Data%20-%20School&filename=Subpopulation%20Attendance%20Data%20-%20School.json_label'
aps24_att_bysubgroup = pd.read_json(aps24_subgroup_url)
aps24_att_bysubgroup.head()
# Out:
#   Annual Attendance Subpopulation Item  Annual Attendance Enrollment  \
# 0                                                               2715
# 1                               Female                         36169
# 2                                 Male                         38001
# 3                             Hispanic                         49169
# 4       American Indian/Alaskan Native                          4001
#
#    Annual Attendance No. of Student in Tier 1  \
# 0                                        1184
# 1                                       13875
# 2                                       14619
# 3                                       17361
# 4                                        1159
#
#    Annual Attendance No. of Student in Tier 2  \
# 0                                         824
# 1                                       11066
# 2                                       11575
# 3                                       15100
# ...

# %% [markdown]
# Base options

# %%
aps24_att_url2 = 'https://nmpedpublic.cloud.looker.com/explore/eLeSugXXKj7J1vz1amRKVh.json_label?apply_formatting=true&apply_vis=true&open_in_browser=yes&title=Overview%20of%20School%20Attendance%20Information%20by%20Grade%20Level&filename=Overview%20of%20School%20Attendance%20Information%20by%20Grade%20Level.json_label'
aps24_att_byschool2 = pd.read_json(aps24_att_url2)
aps24_att_byschool2.head()
list(zip(aps24_att_byschool.columns, aps24_att_byschool2.columns))
# Out:
# [('Annual Attendance  District Name', ' District Name'),
#  ('Annual Attendance  School Name', ' School Name'),
#  ('Annual Attendance Grade Level', 'Grade Level'),
#  ('Annual Attendance Enrollment', 'Enrollment'),
#  ('Annual Attendance No. of Student in Tier 1', 'No. of Student in Tier 1'),
#  ('Annual Attendance No. of Student in Tier 2', 'No. of Student in Tier 2'),
#  ('Annual Attendance No. of Student in Tier 3', 'No. of Student in Tier 3'),
#  ('Annual Attendance No. of Student in Tier 4', 'No. of Student in Tier 4'),
#  ('Annual Attendance Chronically Absent Student',
#   'Chronically Absent Student'),
#  ('Chronic Absentee Rate', 'Chronic Absentee Rate')]

# %%
aps24_subgroup_url2 = 'https://nmpedpublic.cloud.looker.com/explore/HwOnfWOWUATBnL9Bdv6dkS.json_label?apply_formatting=false&apply_vis=false&open_in_browser=yes&title=Subpopulation%20Attendance%20Data%20-%20School&filename=Subpopulation%20Attendance%20Data%20-%20School.json_label'
aps24_att_bysubgroup2 = pd.read_json(aps24_subgroup_url2)
aps24_att_bysubgroup2.head()
# Out:
#   Annual Attendance Subpopulation Item  Annual Attendance Enrollment  \
# 0                                                               2715
# 1                               Female                         36169
# 2                                 Male                         38001
# 3                             Hispanic                         49169
# 4       American Indian/Alaskan Native                          4001
#
#    Annual Attendance No. of Student in Tier 1  \
# 0                                        1184
# 1                                       13875
# 2                                       14619
# 3                                       17361
# 4                                        1159
#
#    Annual Attendance No. of Student in Tier 2  \
# 0                                         824
# 1                                       11066
# 2                                       11575
# 3                                       15100
# ...

# %%
aps24_att_bysubgroup.head()
# Out:
#   Annual Attendance Subpopulation Item  Annual Attendance Enrollment  \
# 0                                                               2715
# 1                               Female                         36169
# 2                                 Male                         38001
# 3                             Hispanic                         49169
# 4       American Indian/Alaskan Native                          4001
#
#    Annual Attendance No. of Student in Tier 1  \
# 0                                        1184
# 1                                       13875
# 2                                       14619
# 3                                       17361
# 4                                        1159
#
#    Annual Attendance No. of Student in Tier 2  \
# 0                                         824
# 1                                       11066
# 2                                       11575
# 3                                       15100
# ...

# %%
filter = aps24_att_byschool2[' School Name'] == 'WHERRY ELEMENTARY'
# filter2 = aps24_att_byschool['Grade Level'] == '09'
aps24_att_byschool2[filter]
# aps24_att_byschool2.columns
# Out:
#     District Name        School Name Grade Level  Enrollment  \
# 29   ALBUQUERQUE   WHERRY ELEMENTARY          04        42.0
# 30   ALBUQUERQUE   WHERRY ELEMENTARY          02        45.0
# 31   ALBUQUERQUE   WHERRY ELEMENTARY          01        32.0
# 32   ALBUQUERQUE   WHERRY ELEMENTARY          03        36.0
# 33   ALBUQUERQUE   WHERRY ELEMENTARY          PK        15.0
# 34   ALBUQUERQUE   WHERRY ELEMENTARY          05        35.0
# 35   ALBUQUERQUE   WHERRY ELEMENTARY          KF        38.0
#
#     No. of Student in Tier 1  No. of Student in Tier 2  \
# 29                       8.0                      18.0
# 30                      12.0                      13.0
# 31                       7.0                       8.0
# 32                       9.0                       9.0
# 33                       3.0                       3.0
# 34                      10.0                      15.0
# 35                       6.0                      16.0
#
# ...

# %% [markdown]
# ### ✅ Manually collect file addresses for clustered schools and APS
# for years 22/23-23/24

# %%
highland_list
# Out:
# ['Wherry Elementary',
#  'Emerson Elementary',
#  'Whittier Elementary',
#  'Wilson Middle',
#  'Van Buren Middle',
#  'Hayes Middle',
#  'Highland High']

# %% [markdown]
# 23/24 clutser schools by subpopulation

# %%
att_df_dict = {}

# %%
att_df_dict['df_aps24_bysubpop'] = 'https://nmpedpublic.cloud.looker.com/explore/HwOnfWOWUATBnL9Bdv6dkS.json_label?apply_formatting=true&apply_vis=true&open_in_browser=yes&title=Subpopulation%20Attendance%20Data%20-%20School&filename=Subpopulation%20Attendance%20Data%20-%20School.json_label'
att_df_dict['df_wherry24_bysubpop'] = 'https://nmpedpublic.cloud.looker.com/explore/4keDuU6eBG5b76psR2olOp.json_label?apply_formatting=true&apply_vis=true&open_in_browser=yes&title=Subpopulation%20Attendance%20Data%20-%20School&filename=Subpopulation%20Attendance%20Data%20-%20School.json_label'
att_df_dict['df_emerson24_bysubpop'] = 'https://nmpedpublic.cloud.looker.com/explore/nR1ZKqKPpIC9SFa1BLKlhh.json_label?apply_formatting=true&apply_vis=true&open_in_browser=yes&title=Subpopulation%20Attendance%20Data%20-%20School&filename=Subpopulation%20Attendance%20Data%20-%20School.json_label'
att_df_dict['df_whittier24_bysubpop']= 'https://nmpedpublic.cloud.looker.com/explore/0CGk4FyqKh6OZweOCynILu.json_label?apply_formatting=true&apply_vis=true&open_in_browser=yes&title=Subpopulation%20Attendance%20Data%20-%20School&filename=Subpopulation%20Attendance%20Data%20-%20School.json_label'
att_df_dict['df_wilson24_bysubpop']= 'https://nmpedpublic.cloud.looker.com/explore/FvdZD98x9j8YacRlNHoUeK.json_label?apply_formatting=true&apply_vis=true&open_in_browser=yes&title=Subpopulation%20Attendance%20Data%20-%20School&filename=Subpopulation%20Attendance%20Data%20-%20School.json_label'
att_df_dict['df_vanburen24_bysubpop']= 'https://nmpedpublic.cloud.looker.com/explore/QJVVJSkXza6KPTz6B7yWQ2.json_label?apply_formatting=true&apply_vis=true&open_in_browser=yes&title=Subpopulation%20Attendance%20Data%20-%20School&filename=Subpopulation%20Attendance%20Data%20-%20School.json_label'
att_df_dict['df_hayes24_bysubpop']= 'https://nmpedpublic.cloud.looker.com/explore/iYTf7A5WvToyXOLXOC1zJP.json_label?apply_formatting=true&apply_vis=true&open_in_browser=yes&title=Subpopulation%20Attendance%20Data%20-%20School&filename=Subpopulation%20Attendance%20Data%20-%20School.json_label'
att_df_dict['df_highland24_bysubpop']= 'https://nmpedpublic.cloud.looker.com/explore/2ak6WDWOnBWY4A8O2XS7m0.json_label?apply_formatting=true&apply_vis=true&open_in_browser=yes&title=Subpopulation%20Attendance%20Data%20-%20School&filename=Subpopulation%20Attendance%20Data%20-%20School.json_label'

# %% [markdown]
# 22/23 cluster schools by subpopulation

# %%
att_df_dict['df_aps23_bysubpop']= 'https://nmpedpublic.cloud.looker.com/explore/9q9p1JhTqUueQFz0GOen3D.json_label?apply_formatting=true&apply_vis=true&open_in_browser=yes&title=Subpopulation%20Attendance%20Data%20-%20School&filename=Subpopulation%20Attendance%20Data%20-%20School.json_label'
att_df_dict['df_wherry23_bysubpop']= 'https://nmpedpublic.cloud.looker.com/explore/EJltQ5EjSkofMVG0bbeTcX.json_label?apply_formatting=true&apply_vis=true&open_in_browser=yes&title=Subpopulation%20Attendance%20Data%20-%20School&filename=Subpopulation%20Attendance%20Data%20-%20School.json_label'
att_df_dict['df_emerson23_bysubpop']= 'https://nmpedpublic.cloud.looker.com/explore/x49amB4XUWQvCTdQiUuAOk.json_label?apply_formatting=true&apply_vis=true&open_in_browser=yes&title=Subpopulation%20Attendance%20Data%20-%20School&filename=Subpopulation%20Attendance%20Data%20-%20School.json_label'
att_df_dict['df_whittier23_bysubpop']= 'https://nmpedpublic.cloud.looker.com/explore/bGyeXfNDOKpZRvj6RqpyHG.json_label?apply_formatting=true&apply_vis=true&open_in_browser=yes&title=Subpopulation%20Attendance%20Data%20-%20School&filename=Subpopulation%20Attendance%20Data%20-%20School.json_label'
att_df_dict['df_wilson23_bysubpop']= 'https://nmpedpublic.cloud.looker.com/explore/Cil1ytbszNG9EElF4GFMS2.json_label?apply_formatting=true&apply_vis=true&open_in_browser=yes&title=Subpopulation%20Attendance%20Data%20-%20School&filename=Subpopulation%20Attendance%20Data%20-%20School.json_label'
att_df_dict['df_vanburen23_bysubpop']= 'https://nmpedpublic.cloud.looker.com/explore/JvI6ZkQZ47Vi7USDr9KR3m.json_label?apply_formatting=true&apply_vis=true&open_in_browser=yes&title=Subpopulation%20Attendance%20Data%20-%20School&filename=Subpopulation%20Attendance%20Data%20-%20School.json_label'
att_df_dict['df_hayes23_bysubpop']= 'https://nmpedpublic.cloud.looker.com/explore/TOaI3Yj9pbL7W0AzFuUuKF.json_label?apply_formatting=true&apply_vis=true&open_in_browser=yes&title=Subpopulation%20Attendance%20Data%20-%20School&filename=Subpopulation%20Attendance%20Data%20-%20School.json_label'
att_df_dict['df_highland23_bysubpop']= 'https://nmpedpublic.cloud.looker.com/explore/z0DmdXIEdracEVze7ONh1h.json_label?apply_formatting=true&apply_vis=true&open_in_browser=yes&title=Subpopulation%20Attendance%20Data%20-%20School&filename=Subpopulation%20Attendance%20Data%20-%20School.json_label'

# %% [markdown]
# 22/23 23/24 by grade

# %%
att_df_dict['df_aps24_bygrade']= 'https://nmpedpublic.cloud.looker.com/explore/LLqqUB8hbn47acgSQdYUn6.json_label?apply_formatting=true&apply_vis=true&open_in_browser=yes&title=Overview%20of%20School%20Attendance%20Information%20by%20Grade%20Level&filename=Overview%20of%20School%20Attendance%20Information%20by%20Grade%20Level.json_label'
att_df_dict['df_aps23_bygrade']= 'https://nmpedpublic.cloud.looker.com/explore/OArrvhUZae7bIcveLVkzeG.json_label?apply_formatting=true&apply_vis=true&open_in_browser=yes&title=Overview%20of%20School%20Attendance%20Information%20by%20Grade%20Level&filename=Overview%20of%20School%20Attendance%20Information%20by%20Grade%20Level.json_label'

# %% [markdown]
# Check to see if columns align

# %%
list(att_df_dict.keys())
# Out:
# ['df_aps24_bysubpop',
#  'df_wherry24_bysubpop',
#  'df_emerson24_bysubpop',
#  'df_whittier24_bysubpop',
#  'df_wilson24_bysubpop',
#  'df_vanburen24_bysubpop',
#  'df_hayes24_bysubpop',
#  'df_highland24_bysubpop',
#  'df_aps23_bysubpop',
#  'df_wherry23_bysubpop',
#  'df_emerson23_bysubpop',
#  'df_whittier23_bysubpop',
#  'df_wilson23_bysubpop',
#  'df_vanburen23_bysubpop',
#  'df_hayes23_bysubpop',
#  'df_highland23_bysubpop',
#  'df_aps24_bygrade',
#  'df_aps23_bygrade']

# %% [markdown]
# Run this cell to rebuild df dictionary

# %%
df_dict = {}
for k, v in att_df_dict.items():
  df_dict[k] = pd.read_json(v)

# %%
# cols_df = pd.DataFrame()

# %%
# for i in att_df_dict.keys():
#   cols_df = pd.concat([cols_df, pd.Series(cols_df_list[i].columns)],axis = 1)

# %%
# cols_df.transpose()

# %%
df_dict['df_wherry24_bysubpop'].transpose()
# Out:
#                                   0       1       2         3   \
# Subpopulation Item                    Female    Male  Hispanic
# Enrollment                        -1     121     122       191
# Tier 1 Students                   -1      25      30        47
# Tier 2 Students                   -1      44      38        56
# Tier 3 Students                   -1      33      37        60
# Tier 4 Students                   -1      19      17        28
# Percent of Student in Tier 1  -1.00%  20.66%  24.59%    24.61%
# Percent of Student in Tier 2  -1.00%  36.36%  31.15%    29.32%
# Percent of Student in Tier 3  -1.00%  27.27%  30.33%    31.41%
# Percent of Student in Tier 4  -1.00%  15.70%  13.93%    14.66%
# Chronic Absentee Rate         -1.00%  42.98%  44.26%    46.07%
# Average Excused Absences        6.25    6.46     7.1      6.71
# Average Unexcused Absences      7.42   11.91   10.79     11.38
#
#                                                           4       5   \
# ...

# %% [markdown]
# ### ✅Add year and school/district/id

# %%
for k, v in df_dict.items():
  print(k)
  # print(k.split('_')[1].split('2')[0])
# Out:
# df_aps24_bysubpop
# df_wherry24_bysubpop
# df_emerson24_bysubpop
# df_whittier24_bysubpop
# df_wilson24_bysubpop
# df_vanburen24_bysubpop
# df_hayes24_bysubpop
# df_highland24_bysubpop
# df_aps23_bysubpop
# df_wherry23_bysubpop
# df_emerson23_bysubpop
# df_whittier23_bysubpop
# df_wilson23_bysubpop
# df_vanburen23_bysubpop
# df_hayes23_bysubpop
# df_highland23_bysubpop
# df_aps24_bygrade
# df_aps23_bygrade

# %%
for k, v in df_dict.items():
  print(k.split('_')[1].split('2')[1])
# Out:
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 4
# 3

# %%
list1 = []
for k, v in df_dict.items():
  list1.append(k.split('_')[1].split('2')[0])

school_rename = dict(zip( list1[0:8], ['Albuqueque District'] + highland_list))
school_rename
# Out:
# {'aps': 'Albuqueque District',
#  'wherry': 'Wherry Elementary',
#  'emerson': 'Emerson Elementary',
#  'whittier': 'Whittier Elementary',
#  'wilson': 'Wilson Middle',
#  'vanburen': 'Van Buren Middle',
#  'hayes': 'Hayes Middle',
#  'highland': 'Highland High'}

# %% [markdown]
# ###  ✅Convert data frames and drop unneed rows and columns
# 🟡 Could clean up data types and nulls more but the datasets are function as of 3/26/2025

# %%
col_order = ['Year','District',  'SchoolName', 'Female', 'Male', 'Hispanic', 'American Indian/Alaskan Native', 'Asian',
       'Black  or African American', 'Caucasian', 'Not Hispanic',
       'Economically Disadvantaged', 'Students with Disabilities',
       'English Language Learners', 'Experiencing Housing Insecurity',
       'Housed']

dist_col_order = ['Year',' District Name', ' School Name', 'Grade Level', 'Enrollment',
       'No. of Student in Tier 1', 'No. of Student in Tier 2',
       'No. of Student in Tier 3', 'No. of Student in Tier 4',
       'Chronically Absent Student', 'Chronic Absentee Rate']

# %%
from os import rename
for k, v in df_dict.items():
  ##Drop %s and reorder columnson subpop, add district, school
  if k.endswith('subpop'):
    df_dict[k] = df_dict[k].transpose().drop(['Percent of Student in Tier 1','Percent of Student in Tier 2','Percent of Student in Tier 3','Percent of Student in Tier 4','Chronic Absentee Rate'], axis = 0)
    df_dict[k].columns = df_dict[k].iloc[0]
    df_dict[k].drop('Subpopulation Item', inplace = True)

    df_dict[k]['SchoolName'] = k.split('_')[1].split('2')[0]
    df_dict[k]['SchoolName'].replace(school_rename)
    df_dict[k]['District'] = 1
 ## add year column
  if k.split('_')[1].split('2')[1] == '3':
    df_dict[k]['Year'] = 2023
  elif k.split('_')[1].split('2')[1] == '4':
    df_dict[k]['Year'] = 2024
  ## Standardize column order
  if k.endswith('subpop'):
    df_dict[k] = df_dict[k][col_order]
  elif k.endswith('grade'):
    df_dict[k] = df_dict[k][dist_col_order]

# %% [markdown]
# ## ✅ Rearrange Columns to make uniform
#
# NOTE: 2024 SEEMS TO HAVE A ENROLLMENT TOTAL COLUMN. 2023 DOESN'T

# %%
cols_df = pd.DataFrame()

for k, v  in df_dict.items():
  cols_df = pd.concat([cols_df, pd.Series(v.columns)],axis = 1)
cols_df.columns = list(att_df_dict.keys())
cols_df
# Out:
#                   df_aps24_bysubpop             df_wherry24_bysubpop  \
# 0                              Year                             Year
# 1                          District                         District
# 2                        SchoolName                       SchoolName
# 3                            Female                           Female
# 4                              Male                             Male
# 5                          Hispanic                         Hispanic
# 6    American Indian/Alaskan Native   American Indian/Alaskan Native
# 7                             Asian                            Asian
# 8        Black  or African American       Black  or African American
# 9                         Caucasian                        Caucasian
# 10                     Not Hispanic                     Not Hispanic
# 11       Economically Disadvantaged       Economically Disadvantaged
# 12       Students with Disabilities       Students with Disabilities
# ...

# %%
df_dict['df_highland24_bysubpop'].head()
# df_dict['df_aps23_bygrade'].head()
# df_dict['df_aps24_bygrade'].columns
# Out:
# Subpopulation Item  Year  District SchoolName Female Male Hispanic  \
# Enrollment          2024         1   highland    503  534      758
# Tier 1 Students     2024         1   highland    167  211      257
# Tier 2 Students     2024         1   highland    137  141      199
# Tier 3 Students     2024         1   highland    117  109      187
# Tier 4 Students     2024         1   highland     82   73      115
#
# Subpopulation Item American Indian/Alaskan Native Asian  \
# Enrollment                                     77    -1
# Tier 1 Students                                34    -1
# Tier 2 Students                                21    -1
# Tier 3 Students                                11    -1
# Tier 4 Students                                11    -1
#
# Subpopulation Item Black  or African American Caucasian Not Hispanic  \
# Enrollment                                 62        73          312
# Tier 1 Students                            31        23          129
# ...

# %% [markdown]
# ## ✅Combine all like tables into one dataframe

# %%
compilation_school_bysubpop = [v for k, v in df_dict.items()][0:-2]
compilation_aps_bygrade = [v for k, v in df_dict.items()][-2:]

# %%
compilation_school_bysubpop_df = pd.DataFrame()
compilation_aps_bygrade_df = pd.DataFrame()

# %% [markdown]
# ## ✅Export compiled json files

# %%
compilation_school_bysubpop_df.to_json('scrapedAttendance_23_24_byschool_by_subpop.json', orient = 'records')
compilation_aps_bygrade_df.to_json('scrapedAttendance_23_24_distrcit_bygrade.json', orient = 'records')
compilation_school_bysubpop_df = pd.concat([v for k, v in df_dict.items()][0:-2])
compilation_aps_bygrade_df= pd.concat([v for k, v in df_dict.items()][-2:])
compilation_school_bysubpop_df.shape, compilation_aps_bygrade_df.shape
# Out:
# ((112, 16), (1002, 11))

# %%
compilation_aps_bygrade_df
# Out:
#      Year  District Name            School Name Grade Level  Enrollment  \
# 0    2024   ALBUQUERQUE   A. MONTOYA ELEMENTARY          05        68.0
# 1    2024   ALBUQUERQUE   A. MONTOYA ELEMENTARY          02        61.0
# 2    2024   ALBUQUERQUE   A. MONTOYA ELEMENTARY          01        48.0
# 3    2024   ALBUQUERQUE   A. MONTOYA ELEMENTARY          04        68.0
# 4    2024   ALBUQUERQUE   A. MONTOYA ELEMENTARY          KF        54.0
# ..    ...            ...                    ...         ...         ...
# 496  2023    ALBUQUERQUE       JEFFERSON MIDDLE          07       224.0
# 497  2023    ALBUQUERQUE       JEFFERSON MIDDLE          06       225.0
# 498  2023    ALBUQUERQUE    JIMMY CARTER MIDDLE          07       197.0
# 499  2023    ALBUQUERQUE    JIMMY CARTER MIDDLE          OS         1.0
# 500  2023           None                   None        None         NaN
#
#      No. of Student in Tier 1  No. of Student in Tier 2  \
# ...

# %% [markdown]
# Flavor text for GitHub:
#
# Data scraping NM PED Annual Attendance report for district by grade and individual school attendance reports for target cluster.
# Clean and compiled datasets into usable json files.
